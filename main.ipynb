# %%
import sys
sys.path.append("src")

from build_cnn_model import build_cnn_model
from data_pipeline_clean import train_generator, val_generator, test_generator, class_labels, class_weights

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import CategoricalCrossentropy
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import tensorflow as tf

# -------------------------------
input_shape = (128, 128, 3)   
num_classes = len(class_labels)

model = build_cnn_model(input_shape, num_classes)

model.compile(
    optimizer='adam',
    loss=CategoricalCrossentropy(),
    metrics=['accuracy']
)

model.summary()


# -------------------------------
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    'best_model.h5', 
    monitor='val_loss', 
    save_best_only=True, 
    verbose=1
)

# -------------------------------
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=40,
    class_weight=class_weights,
    callbacks=[early_stop, checkpoint]
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys
#       2 sys.path.append("src")
# ----> 4 from build_cnn_model import build_cnn_model
#       5 from data_pipeline_clean import train_generator, val_generator, test_generator, class_labels, class_weights
#       7 from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
#
# File d:\college\رابعه\ترم اول\cs417\cs417-Project\src\build_cnn_model.py:1
# ----> 1 import tensorflow as pd
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
#
# ModuleNotFoundError: No module named 'tensorflow'
